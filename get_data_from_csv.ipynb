# %%
import json
import pandas as pd
import numpy as np
# msg_recieved = json.load("txt_output_16.txt")

# with open("./test_data/44-1_001-C01_2D.json") as json_file:
# with open("./test_data/1-10_001-C12_2D.json") as json_file:
with open("/home/lab23/smoke/2D/5-1/5-1_001-C01_2D.json") as json_file:
# with open("/home/lab23/smoke/2D/45-1/45-1_001-C01_2D.json") as json_file:

    json_recieved = json.load(json_file)
#     print(json.dumps(json_recieved, indent=2))
    print("categories")
    print(len(json_recieved["categories"][0]["keypoints"]))
#     print((json_recieved["categories"][0]["keypoints"]))
    kp_categories = json_recieved["categories"][0]["keypoints"]
    kp_categories = np.reshape(kp_categories, (-1,3))
    print(kp_categories)
    print(len(kp_categories))
    
    print("images")
    print(len(json_recieved["images"]))
#     print(json_recieved["images"])
    
    print("total annotation cnt")
    print(len(json_recieved["annotations"]))
    print(json.dumps(json_recieved["annotations"], indent=2))

#     print("annotation")
#     print(len(json_recieved["annotations"][0]["keypoints"]))
#     print(json.dumps(json_recieved["annotations"][0]["keypoints"], indent=2))



    ID = []
    Keypoints = []

    for id in json_recieved['images']:
        print(id['img_path'])
        ID.append(id['img_path'].split("/")[-1][:-8])

    for val in json_recieved['annotations']:
        Keypoints.append(val['keypoints'])



#     df = pd.DataFrame({"ID" : ID*2,
#                        "Keypoints" : Keypoints})
#     df.show()
    
print(ID)
print(len(ID))
print(Keypoints)
print(len(Keypoints))
# Out:
# categories
# 48
# [['right_ankle_x' 'right_ankle_y' 'right_ankle_view']
#  ['right_knee_x' 'right_knee_y' 'right_knee_view']
#  ['right_hip_x' 'right_hip_y' 'right_hip_view']
#  ['left_hip_x' 'left_hip_y' 'left_hip_view']
#  ['left_knee_x' 'left_knee_y' 'left_knee_view']
#  ['left_ankle_x' 'left_ankle_y' 'left_ankle_view']
#  ['pelvis_x' 'pelvis_y' 'pelvis_view']
#  ['throax_x' 'throax_y' 'throax_view']
#  ['neck_x' 'neck_y' 'neck_view']
#  ['head_top_x' 'head_top_y' 'head_top_view']
#  ['right_wrist_x' 'right_wrist_y' 'right_wrist_view']
#  ['right_elbow_x' 'right_elbow_y' 'right_elbow_view']
#  ['right_shoulder_x' 'right_shoulder_y' 'right_shoulder_view']
#  ['left_shoulder_x' 'left_shoulder_y' 'left_shoulder_view']
#  ['left_elbow_x' 'left_elbow_y' 'left_elbow_view']
#  ['left_wrist_x' 'left_wrist_y' 'left_wrist_view']]
# 16
# images
# 15
# total annotation cnt
# 30
# [
#   {
#     "img_no": 3992287,
#     "person_no": 1,
#     "bbox": [
#       898.0,
#       284.0,
#       1113.0,
#       696.0
#     ],
#     "keypoints": [
#       967.0,
#       652.0,
#       2.0,
#       981.0,
#       575.0,
#       2.0,
#       991.0,
#       484.0,
#       2.0,
#       1030.0,
#       486.0,
#       2.0,
#       1044.0,
#       578.0,
#       2.0,
#       1061.0,
#       652.0,
#       2.0,
#       1010.0,
#       486.0,
#       2.0,
#       1013.0,
#       422.0,
#       2.0,
#       1012.0,
#       386.0,
#       2.0,
#       1009.0,
#       333.0,
#       2.0,
#       938.0,
#       333.0,
#       2.0,
#       963.0,
#       362.0,
#       2.0,
#       984.0,
#       393.0,
#       2.0,
#       1037.0,
#       400.0,
#       2.0,
#       1069.0,
#       389.0,
#       2.0,
#       1095.0,
#       371.0,
#       2.0
#     ],
#     "num_keypoint": 16
#   },
#   {
#     "img_no": 3
# 6-7_603-C09


x_data = df[['Keypoints']]
t_data = np.zeros(len(x_data),)
print(x_data)
print(len(x_data))
print(x_data.shape)
# print(t_data)
# t_data = df[['ID']]

x_data_mod = get_keypoints_in_float(x_data)

# print(keypoint.shape)
# print(len(keypoint))
    
print(type(x_data_mod))
print(x_data_mod)
print(x_data_mod.shape)
print(len(x_data_mod))
print(x_data_mod[0])
print(type(x_data_mod[0])) # <class 'str'>
# Out:
#                                             Keypoints
# 0   [967.0, 652.0, 2.0, 981.0, 575.0, 2.0, 991.0, ...
# 1   [949.0, 657.0, 2.0, 947.0, 582.0, 2.0, 955.0, ...
# 2   [970.0, 649.0, 2.0, 995.0, 575.0, 2.0, 1006.0,...
# 3   [950.0, 656.0, 2.0, 939.0, 582.0, 2.0, 940.0, ...
# 4   [1037.0, 649.0, 2.0, 1037.0, 572.0, 2.0, 1036....
# 5   [939.0, 659.0, 2.0, 913.0, 574.0, 2.0, 895.0, ...
# 6   [1077.0, 656.0, 2.0, 1059.0, 580.0, 2.0, 1055....
# 7   [850.0, 653.0, 2.0, 864.0, 575.0, 2.0, 868.0, ...
# 8   [1084.0, 656.0, 2.0, 1070.0, 576.0, 2.0, 1076....
# 9   [850.0, 657.0, 2.0, 850.0, 571.0, 2.0, 850.0, ...
# 10  [1106.0, 654.0, 2.0, 1113.0, 571.0, 1.0, 1152....
# 11  [861.0, 646.0, 2.0, 851.0, 567.0, 2.0, 829.0, ...
# 12  [1131.0, 654.0, 1.0, 1138.0, 570.0, 2.0, 1148....
# 13  [871.0, 656.0, 2.0, 867.0, 577.0, 2.0, 865.0, ...
# 14  [1123.0, 657.0, 2.0, 1111.0, 575.0, 2.0, 1126....
# 15  [877.0, 654.0, 2.0, 884.0, 573.0, 2.0, 881.0, ...
# 16  [1091.0, 645.0, 2.0, 1066.0, 574.0, 2.0, 1082....
# 17  [912.0, 641.0, 2.0, 946.0, 560.0, 2.0, 928.0, ...
# 18  [1059.0, 658.0, 2.0, 1051.0, 583.0, 2.0, 1069....
# 19  [945.0, 655.0, 2.0, 952.0, 568.0, 2.0, 951.0, ...
# 20  [1059.0, 658.0, 2.0, 1059.0, 584.0, 2.0, 1070....
# 21  [945.0, 655.0, 2.0, 948.0, 566.0, 2.0, 951.0, ...
# 22  [1059.0, 658.0, 2.0, 1059.0, 584.0, 2.0, 1070....
# 23  [945.0, 655.0, 2.0, 948.0, 566.0, 2.0, 951.0, ...
# 24  [1093.0, 654.0, 2.0, 1073.0, 579.0, 2.0, 1085....
# 25  [945.0, 655.0, 2.0, 948.0, 566.0, 2.0, 944.0, ...
# 26  [1147.0, 659.0, 2.0, 1125.0, 584.0, 2.0, 1134....
# 27  [885.0, 653.0, 2.0, 923.0, 571.0, 2.0, 923.0, ...
# 28  [1164.0, 656.0, 2.0, 1159.0, 574.0, 2.0, 1178....
# 29  [887.0, 652.0, 2.0, 899.0, 565.0, 2.0, 888.0, ...
# 30
# (30, 1)
# (30,)
# 100%|████████████████████████████████████████| 30/30 [00:00<00:00, 12929.42it/s]
# <class 'numpy.ndarray'>
# [[ 967.  652.  981.  575.  991.  484. 1030.  486. 1044.  578. 1061.  652.
#   1009.  333.  938.  333.  963.  362.  984.  393. 1037.  400. 1069.  389.
#   1095.  371.]
#  [ 949.  657.  947.  582.  955.  500.  910.  501.  876.  582.  851.  652.
#  [1059.  658. 1051.  583. 1069.  473. 1029.  473. 1016.  580. 1024.  660.
#   1015.  320.  987.  370. 1012.  372. 1048.  381.  996.  382.  942.  394.
#    971.  387.]
#  [ 945.  655.  952.  568.  951.  477.  985.  480.  982.  567.  983.  650.
#   1039.  335.  960.  497.  958.  442.  966.  392. 1015.  421. 1004.  467.
#    996.  512.]
#  [1059.  658. 1059.  584. 1070.  474. 1027.  476. 1016.  580. 1024.  660.
#   1015.  324.  985.  380. 1014.  395. 1046.  391.  996.  382.  942.  394.
#    966.  395.]
#  [ 945.  655.  948.  566.  951.  477.  985.  480.  982.  567.  983.  650.
#   1039.  335.  955.  503.  954.  446.  966.  392. 1024.  414. 1002.  463.
#    993.  513.]
#  [1059.  658. 1059.  584. 1070.  474. 1027.  476. 1016.  580. 1024.  660.
#   1011.  324.  985.  380. 1014.  395. 1045.  396.  996.  382.  940.  395.
#    966.  395.]
#  [ 945.  655.  948.  566.  951.  477.  985.  480.  982.  567.  983.  650.
#   1039.  335.  955.  503.  954.  446.  966.  392. 1024.  414. 1002.  463.
#    992.  516.]
#  [1093.  654. 1073.  579. 1085.  479. 1040.  481. 1029.  582. 1024.  660.
#   1033.  321.  993.  390. 1030.  409. 1059.  390.  999.  386.  955.  397.
#    923.  405.]
#  [ 945.  655.  948.  566.  944.  476.  980.  480.  982.  567.  983.  650.
#   1037.  339.  949.  502.  950.  444.  966.  392. 1024.  414.  997.  470.
#    995.  511.]
#  [1147.  659. 1125.  584. 1134.  495. 1088.  495. 1052.  591. 1021.  655.
#   1082.  324. 1070.  448. 1104.  430. 1112.  393. 1076.  395. 1044.  417.
#   1007.  434.]
#  [ 885.  653.  923.  571.  923.  492.  963.  492.  976.  571.  978.  658.
#    989.  324.  945.  497.  930.  443.  940.  388.  974.  405.  974.  465.
#    986.  505.]
#  [1164.  656. 1159.  574. 1178.  482. 1144.  482. 1114.  573. 1142.  651.
#   1124.  313. 1154.  493. 1164.  446. 1165.  385. 1119.  388. 1127.  443.
#   1119.  497.]
#  [ 887.  652.  899.  565.  888.  487.  930.  487.  939.  555.  907.  641.
#    926.  312.  920.  491.  897.  441.  899.  379.  931.  403.  916.  460.
#    923.  503.]]
# (30, 26)
# 30
# [ 967.  652.  981.  575.  991.  484. 1030.  486. 1044.  578. 1061.  652.
#  1009.  333.  938.  333.  963.  362.  984.  393. 1037.  400. 1069.  389.
#  1095.  371.]
# <class 'numpy.ndarray'>

# %% [markdown]
# # 목적: 데이터 전처리 후 Train/Test/Validation set 생성

# %%
# 목표: DACON Baseline 코드를 이용해 LSTM을 활용한 학습 진행

import json
import numpy as np
import pandas as pd

import io

import os
import matplotlib.image as img
import matplotlib.pyplot as plt
import itertools
from tqdm import tqdm

# import tensorflow as tf
# from sklearn.linear_model import LogisticRegression
# from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
# from scipy import stats

# %% [markdown]
# ## 학습에서 사용하지 않거나 실제 예측에서 사용할 수 없는 keypoint 제거 함수

# %%
def remove_unused_annotation(keypoint):
    # 학습데이터는 모두 2D데이터
    # 따라서, 사용하지 않는 값 (_, _, 2)을 제거
    keypoint = keypoint.reshape(-1, 3)
    result = np.delete(keypoint, 2, axis=1)
    
    # 실제 예측에서 사용할 수 없는 Annotation 제거
    result = np.delete(result, [6,7,8], axis=0)
    result = result.reshape(1,-1)
    
    return result

# %% [markdown]
# ## Dataframe으로 변환한 데이터의 최소/최대/최빈값 출력 함수

# %%
def print_mod_min_max(dataframe):
    min_data = dataframe.min()
    max_data = dataframe.max()
    mod_data = dataframe.mode()
    print(max(mod_data.iloc[:, 0]))
    print("/ Min : {} \n/ Max: {} \n/ Mode Max: {}\n".format(min_data, max_data, max(mod_data.iloc[:, 0])))

# %% [markdown]
# ## ID와 Person 데이터를 이용해 각 Person number 별 데이터를 분리 정렬하는 코드
# - 최종 결과는 모든 데이터를 취합한 하나의 Dataframe

# %%
def seperate_people(dataframe):
    # ['Time', 'ID', 'Person', 'Keypoints']
    max_person_no = dataframe['Person'].max()
    
    if max_person_no==1 :
        return dataframe
    else:
        new_df = pd.DataFrame( columns={'Time', 'ID', 'Person', 'Keypoints'})
        id_data = dataframe[['ID']].drop_duplicates(['ID'])
        id_data = id_data.reset_index(drop=True)

        for k in tqdm(range(0, len(id_data))):
            pre_data = dataframe[ dataframe['ID']==id_data.at[k, 'ID'] ]
            
            for i in range(0, max_person_no):
                data = pre_data[ pre_data['Person']==i+1 ]
                data = data.drop('Time', axis=1)
                data = data.reset_index(drop=True)
                data = data.reset_index()
                data.rename(columns={'index':'Time'}, inplace=True)
#                 print(data)
                new_df = new_df.append(data)
                
        new_df = new_df[['Time', 'ID', 'Person', 'Keypoints']]
        new_df.reset_index(drop=True, inplace=True)
        return new_df

# %% [markdown]
# ## frame 사이즈만큼 남도록 남는 annotation을 삭제하는 코드
# - 전체 Time수를 frame으로 나눠 몫을 반올림한 후, 그 값을 이용해 Time을 modular 연산한 결과가 0인 데이터를 남긴다
# - 이렇게 하면 데이터가 frame 수만큼 남거나, frame+1 만큼 남게 된다
# - 전체 길이를 마지막으로 체크하여 frame보다 클 경우 해당 데이터를 버리고 reindexing 한다

# %%
def drop_keypoints_to_size(dataframe, frame):
    # ['Time', 'ID', 'Person', 'Keypoints']
#     max_person_no = dataframe['Person'].max()

    result = pd.DataFrame( columns={'Time', 'ID', 'Person', 'Keypoints'} )

    id_data = dataframe[['ID']].drop_duplicates(['ID'])
    id_data = id_data.reset_index(drop=True)

#     for k in tqdm(range(0, 3)):
    for k in tqdm(range(0, len(id_data))):
        pre_data = dataframe[ dataframe['ID']==id_data.at[k, 'ID'] ]
        max_person_no = pre_data['Person'].max()

        for i in range(0, max_person_no):
            data = pre_data[ pre_data['Person']==i+1 ]
    #         print(data)
            max_time_no = data['Time'].max() +1
            div_size = (max_time_no / frame)

            if div_size<1:
                # 주어진 사이즈보다 작음
                pass
            else:
                div_size = round(div_size)
#                 print(div_size)

                # 필요 이상의 값을 찾아와 drop
                drop_index = data[ data['Time']%div_size>0 ].index
                data.drop(drop_index, inplace=True)

                # Time 값 data
                data = data.drop('Time', axis=1)
                data = data.reset_index(drop=True)
                data = data.reset_index()
                data.rename(columns={'index':'Time'}, inplace=True)
#             print(data[['Time', 'ID', 'Person']])
#             print("len(data)")
#             print(len(data))
            data_len = len(data)

            if data_len>=(frame+1) :
                # 지정 개수 이상일 시 남는 데이터 drop
                drop_index = data[ data['Time']>=frame ].index
#                 print(drop_index)
                data.drop(drop_index, inplace=True)
#                 data.drop(frame, inplace=True)
            
            elif data_len<(frame) :
                # 지정 개수 미만일 시 남는 마지막 데이터를 복사해서 붙인다
                for i in range(0, frame-data_len):
                    data = data.append(data.loc[ data_len-1 ])
                
                data = data.drop('Time', axis=1)
                data = data.reset_index(drop=True)
                data = data.reset_index()
                data.rename(columns={'index':'Time'}, inplace=True)
#             print(data)
#             print("len(data) (2)")
#             print(len(data))
            result = result.append(data)

    result = result[['Time', 'ID', 'Person', 'Keypoints']]
    result.reset_index(drop=True, inplace=True)
    return result


# test_index = df2[df2['ID'].str.startswith('45-')].index
# test_df = df2.loc[test_index]
# test_df.reset_index(drop=True, inplace=True)

# new_test_df = drop_keypoints_to_size(test_df, 8)
# new_test_df


# print(len(new_df_5))
# new_df_5_dropped = drop_keypoints_to_size(new_df_5, 8)
# new_df_5_dropped.head(50)

# new_df_5_dropped.describe()
# result.head(50)

# new_df['Time'].describe()
# new_df[ new_df['Time']==8 ]

# %% [markdown]
# ## ID 데이터를 이용해 train/test set을 분리하는 코드
# - split_my_train_test(dataframe):
#     - 인덱스 형식 = `['Time', 'ID', 'Person', 'Keypoints', 'Answer']`
# - split_my_train_test_set(dataframe):
#     - 인덱스 형식 = `['Time', 'ID', 'Keypoints', 'Answer']`

# %%
def split_my_train_test(dataframe):
    # ['Time', 'ID', 'Person', 'Keypoints']

    id_data = dataframe[['ID', 'Answer']].drop_duplicates(['ID'])
    id_data = id_data.reset_index(drop=True)

    train_x_data, test_x_data, train_t_data, test_t_data = \
    train_test_split(id_data.drop('Answer', axis=1, inplace=False),
                     id_data['Answer'],
                     test_size=0.3,
                     stratify=id_data['Answer'],
                     random_state=0)
    train_x_data.reset_index(drop=True, inplace=True)
    test_x_data.reset_index(drop=True, inplace=True)
    
    result_train = pd.DataFrame( columns={'Time', 'ID', 'Person', 'Keypoints', 'Answer'} )
    result_test = pd.DataFrame( columns={'Time', 'ID', 'Person', 'Keypoints', 'Answer'} )

#     for k in tqdm(range(0, 3)):
    for k in tqdm(range(0, len(train_x_data))):
        pre_data = dataframe[ dataframe['ID']==train_x_data.at[k, 'ID'] ]
        result_train = result_train.append(pre_data)
    
    for k in tqdm(range(0, len(test_x_data))):
        pre_data = dataframe[ dataframe['ID']==test_x_data.at[k, 'ID'] ]
        result_test = result_test.append(pre_data)

    result_train = result_train[['Time', 'ID', 'Person', 'Keypoints', 'Answer']]
    result_test = result_test[['Time', 'ID', 'Person', 'Keypoints', 'Answer']]
    
    result_train.reset_index(drop=True, inplace=True)
    result_test.reset_index(drop=True, inplace=True)
    
#     result_train.to_csv('./train/dropped_train.csv', mode='w', header = True, index=False)
#     result_test.to_csv('./train/dropped_test.csv', mode='w', header = True, index=False)
    return result_train, result_test, train_t_data, test_t_data

# %%
def split_my_train_test_set(dataframe):
    # ['Time', 'ID', 'Keypoints', 'Answer']

    id_data = dataframe[['ID', 'Answer']].drop_duplicates(['ID'])
    id_data = id_data.reset_index(drop=True)

    train_x_data, test_x_data, train_t_data, test_t_data = \
    train_test_split(id_data.drop('Answer', axis=1, inplace=False),
                     id_data['Answer'],
                     test_size=0.3,
                     stratify=id_data['Answer'],
                     random_state=0)
    train_x_data.reset_index(drop=True, inplace=True)
    test_x_data.reset_index(drop=True, inplace=True)
    train_t_data.reset_index(drop=True, inplace=True)
    test_t_data.reset_index(drop=True, inplace=True)
    
    result_train = pd.DataFrame( columns={'Time', 'ID', 'Keypoints', 'Answer'} )
    result_test = pd.DataFrame( columns={'Time', 'ID', 'Keypoints', 'Answer'} )

#     for k in tqdm(range(0, 3)):
    for k in tqdm(range(0, len(train_x_data))):
        pre_data = dataframe[ dataframe['ID']==train_x_data.at[k, 'ID'] ]
        result_train = result_train.append(pre_data)
    
    for k in tqdm(range(0, len(test_x_data))):
        pre_data = dataframe[ dataframe['ID']==test_x_data.at[k, 'ID'] ]
        result_test = result_test.append(pre_data)

    result_train = result_train[['Time', 'ID', 'Keypoints', 'Answer']]
    result_test = result_test[['Time', 'ID', 'Keypoints', 'Answer']]
    
    result_train.reset_index(drop=True, inplace=True)
    result_test.reset_index(drop=True, inplace=True)
    
    return result_train, result_test, train_t_data, test_t_data

# %% [markdown]
# ## Dataframe에서 가져온 str 형태의 데이터를 float array로 변환하는 함수

# %%
KEYPOINT = 32
KEYPOINT_MOD = 26

def get_keypoints_in_float(string_data):
    keypoint = np.array(string_data['Keypoints'].values)
    print(keypoint.shape)
    keypoint_arr = np.empty((0,KEYPOINT_MOD), float)

#     i=0
    for i in tqdm(range(0, len(keypoint))) :
        keypoint[i] = keypoint[i].replace("[", "")
        keypoint[i] = keypoint[i].replace("]", "")
        keypoint[i] = keypoint[i].split(',')
#         print(i)
        # keypoint[0]
        
        temp = np.array(keypoint[i])
        arr_index = np.where(temp == ' None')
#         print(arr_index[0])
#         print(len(arr_index[0]))
#         print(type(arr_index[0]))

        if (len(arr_index[0])>0):
            for index in arr_index[0] :
                keypoint[i][index] = '0'
            print(keypoint[i])

        nd_array = np.array(keypoint[i])
        nd_array = nd_array.astype(np.float)
    #     print("nd_array")
    #     print(nd_array)
    #     print(nd_array.shape)

        # 학습데이터는 모두 2D데이터
        # 사용하지 않는 값과 사용할 수 없는 annotation을 제거
        result = remove_unused_annotation(nd_array)
    #     print(result)
    #     print(result.shape)
    #     print(type(result[0][0]))

        keypoint_arr = np.append(keypoint_arr, result, axis=0)
    return keypoint_arr

# %% [markdown]
# ## 이 아래로 CSV 생성 및 변환 코드가 이어진다.
# ### train_raw.csv 생성
# - person number에 따라 데이터에 분리한 뒤, train_raw.csv에 저장한다
# - 일부 수동으로 5,6,41,42,43,45를 csv 파일에 저장하였음

# %%
import csv

with open('./train/train_raw.csv', 'w', newline='') as csvfile:
    csv_initializer = csv.writer(csvfile, delimiter=',')
    csv_initializer.writerow(['Time', 'ID', 'Person', 'Keypoints'])
    csvfile.close()

# %%
# import numpy as np
# import pandas as pd
# 5,6,41,42,43,45

df = pd.read_csv('./test_data/45.csv', sep=',')
print(type(df))
df.head(10)

#  25 7 14 >> 7 >> 다른것들도 7개만 남게 자르고

new_df = seperate_people(df)
new_df.to_csv('./train/train_raw.csv',  mode='a', header = False)
new_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         Time            ID  Person  \
# 0          0  45-1_001-C01       1
# 1          1  45-1_001-C01       1
# 2          2  45-1_001-C01       1
# 3          3  45-1_001-C01       1
# 4          4  45-1_001-C01       1
# ...      ...           ...     ...
# 188313    10  45-6_617-C03       1
# 188314    11  45-6_617-C03       1
# 188315    12  45-6_617-C03       1
# 188316    13  45-6_617-C03       1
# 188317    14  45-6_617-C03       1
#
#                                                 Keypoints
# 0       [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 941.0, ...
# 1       [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 941.0, ...
# 2       [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 941.0, ...
# 3       [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 930.0, ...
# 4       [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 930.0, ...
# ...                                                   ...
# 188313  [1074.0, 952.0, 2.0, 1042.0, 859.0, 2.0, 1030....
# 188314  [1011.0, 919.0, 2.0, 940.0, 855.0, 2.0, 969.0,...
# 188315  [862.0, 951.0, 2.0, 885.0, 855.0, 2.0, 920.0, ...
# 188316  [856.0, 959.0, 2.0, 852.0, 859.0, 2.0, 860.0, ...
# 188317  [856.0, 956.0, 2.0, 831.0, 862.0, 2.0, 823.0, ...
#
# [188318 rows x 4 columns]

# %% [markdown]
# ### ID 데이터를 테스트

# %%
# import numpy as np
# import pandas as pd
# 5,6,41,42,43,45

df = pd.read_csv('./test_data/45.csv', sep=',')
print(type(df))
# df.head(10)
id_data = df[['ID']].drop_duplicates(['ID'])
id_data
# df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                   ID
# 0       45-1_001-C01
# 19      45-1_001-C02
# 40      45-1_001-C03
# 61      45-1_001-C04
# 82      45-1_001-C05
# ...              ...
# 188243  45-6_616-C11
# 188258  45-6_616-C12
# 188273  45-6_617-C01
# 188288  45-6_617-C02
# 188303  45-6_617-C03
#
# [10420 rows x 1 columns]

# %% [markdown]
# ### train_raw2.csv 생성
# - train_raw.csv를 가져와 index를 재설정한 데이터

# %%
# import numpy as np
# import pandas as pd


df = pd.read_csv('./train/train_raw.csv', sep=',')
print(type(df))
print(len(df))
# df.describe()

df = df.reset_index(drop=True) 
# df

df.to_csv('./train/train_raw2.csv',  mode='w', header = True, index=False)

#  25 7 14 >> 7 >> 다른것들도 7개만 남게 자르고
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 478629

# %% [markdown]
# ### ID data를 이용해 몇 종류의 데이터가 있는지 확인
# - 총 478629개 데이터, 23260개 ID

# %%
df2 = pd.read_csv('./train/train_raw2.csv', sep=',')
df2
# Out:
#         Time            ID  Person  \
# 0          0   5-1_001-C01       1
# 1          1   5-1_001-C01       1
# 2          2   5-1_001-C01       1
# 3          3   5-1_001-C01       1
# 4          4   5-1_001-C01       1
# ...      ...           ...     ...
# 478624    10  45-6_617-C03       1
# 478625    11  45-6_617-C03       1
# 478626    12  45-6_617-C03       1
# 478627    13  45-6_617-C03       1
# 478628    14  45-6_617-C03       1
#
#                                                 Keypoints
# 0       [967.0, 652.0, 2.0, 981.0, 575.0, 2.0, 991.0, ...
# 1       [970.0, 649.0, 2.0, 995.0, 575.0, 2.0, 1006.0,...
# 2       [1037.0, 649.0, 2.0, 1037.0, 572.0, 2.0, 1036....
# 3       [1077.0, 656.0, 2.0, 1059.0, 580.0, 2.0, 1055....
# 4       [1084.0, 656.0, 2.0, 1070.0, 576.0, 2.0, 1076....
# ...                                                   ...
# 478624  [1074.0, 952.0, 2.0, 1042.0, 859.0, 2.0, 1030....
# 478625  [1011.0, 919.0, 2.0, 940.0, 855.0, 2.0, 969.0,...
# 478626  [862.0, 951.0, 2.0, 885.0, 855.0, 2.0, 920.0, ...
# 478627  [856.0, 959.0, 2.0, 852.0, 859.0, 2.0, 860.0, ...
# 478628  [856.0, 956.0, 2.0, 831.0, 862.0, 2.0, 823.0, ...
#
# [478629 rows x 4 columns]

# %%
id_data = df2[['ID']].drop_duplicates(['ID'])
id_data
# Out:
#                   ID
# 0        5-1_001-C01
# 30       5-1_001-C02
# 60       5-1_001-C03
# 90       5-1_001-C04
# 120      5-1_001-C06
# ...              ...
# 478554  45-6_616-C11
# 478569  45-6_616-C12
# 478584  45-6_617-C01
# 478599  45-6_617-C02
# 478614  45-6_617-C03
#
# [23260 rows x 1 columns]

# %% [markdown]
# ### 최빈값, 최솟값, 최댓값을 확인하기 위한 함수

# %%
# 5,6,41,42,43,45
# 5: 25 ~35
# 6: 7 ~41
# 41: 14 ~32
# 42: 9 ~32
# 43: 13 ~32
# 45: 8 ~26
old_df = pd.read_csv('./test_data/45.csv', sep=',')
print(type(old_df))
old_df.head(10)



mode_num = old_df[['Time']]
# display(old_df[['Time']].mode())
display(old_df[['Time']].max())
mode_num = old_df[['Person']]
display(old_df[['Person']].mode())
display(old_df[['Person']].max())


# print_mod_min_max(mode_num)
# mode_num = old_df[['Person']]
# print_mod_min_max(mode_num)

# df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Time    26
# dtype: int64
#    Person
# 0       1
# Person    1
# dtype: int64

# %% [markdown]
# ### 남는 frame을 drop하여 Time 값을 모두 동일하게 맞추는 코드
# #### 동일하게 맞춘 뒤, drop된 값을 ~~train_droped.csv로 저장한다.~~ --> new_df에 가지고 있는다
# - 이유를 알 수 없으나, 간혹 없어야하는 Time number를 가지고 있는 데이터가 있음
# - 해당 데이터를 찾아 삭제한 뒤, reindexing한다

# %%
# import numpy as np
# import pandas as pd
# 5,6,41,42,43,45

# df2.head(10)
# print(type(df2))

new_df = drop_keypoints_to_size(df2, 8)
# new_df = new_df.reset_index(drop=True)
# new_df
# new_df['Time'].describe()



## 혹시 모르니까 'Time'==frame에 해당하는 인덱스를 찾고 삭제
drop_index = new_df[ new_df['Time']==8 ].index
print(drop_index)

new_df.drop(drop_index, inplace=True)
new_df.reset_index(drop=True, inplace=True)

new_df
# new_df.to_csv('./train/train_droped.csv', mode='w', header = True, index=False)

# round(1.5)

# test_45 = drop_keypoints_to_size(new_test_df[ new_test_df['ID']=='45-4_052-C05' ], 8)
# test_45
# Out:
#   0%|                                                 | 0/23260 [00:00<?, ?it/s]/home/ubuntu/anaconda3/envs/data_env24/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# 100%|█████████████████████████████████████| 23260/23260 [13:25<00:00, 28.87it/s]
# Int64Index([54448, 157905, 163762], dtype='int64')
#        Time            ID Person  \
# 0         0   5-1_001-C01      1
# 1         1   5-1_001-C01      1
# 2         2   5-1_001-C01      1
# 3         3   5-1_001-C01      1
# 4         4   5-1_001-C01      1
# ...     ...           ...    ...
# 199811    3  45-6_617-C03      1
# 199812    4  45-6_617-C03      1
# 199813    5  45-6_617-C03      1
# 199814    6  45-6_617-C03      1
# 199815    7  45-6_617-C03      1
#
#                                                 Keypoints
# 0       [967.0, 652.0, 2.0, 981.0, 575.0, 2.0, 991.0, ...
# 1       [1037.0, 649.0, 2.0, 1037.0, 572.0, 2.0, 1036....
# 2       [1084.0, 656.0, 2.0, 1070.0, 576.0, 2.0, 1076....
# 3       [1131.0, 654.0, 1.0, 1138.0, 570.0, 2.0, 1148....
# 4       [1091.0, 645.0, 2.0, 1066.0, 574.0, 2.0, 1082....
# ...                                                   ...
# 199811  [1225.0, 952.0, 2.0, 1210.0, 850.0, 2.0, 1197....
# 199812  [1108.0, 947.0, 2.0, 1103.0, 849.0, 2.0, 1123....
# 199813  [1074.0, 952.0, 2.0, 1042.0, 859.0, 2.0, 1030....
# 199814  [862.0, 951.0, 2.0, 885.0, 855.0, 2.0, 920.0, ...
# 199815  [856.0, 956.0, 2.0, 831.0, 862.0, 2.0, 823.0, ...
#
# [199816 rows x 4 columns]

# %% [markdown]
# #### 필요 이상의 Time 값을 가진 데이터 확인
# - 이유를 알 수 없으나, 간혹 없어야하는 Time number를 가지고 있는 데이터가 있음
# - 해당 데이터를 찾아 삭제한 뒤, reindexing한다

# %%
# Time == 8인 데이터에 대해 확인
new_df[ new_df['Time']==8 ]

# drop_index = new_df[ new_df['Time']==8 ].index
# print(drop_index)
# # new_test_df.loc[41448]
# new_df.drop(drop_index, inplace=True)
# new_df.reset_index(drop=True, inplace=True)
# Out:
# Empty DataFrame
# Columns: [Time, ID, Person, Keypoints]
# Index: []

# %% [markdown]
# ### Answer 란에 정답 라벨을 삽입
# - '45-'로 시작하는 데이터에 대하여 1
# - 그 외의 데이터에 대하여 0

# %%
# 정답 삽입
# new_df = df2
new_df['Answer'] = 0
answer_row = new_df[new_df['ID'].str.startswith('45-')].index
new_df.loc[answer_row, 'Answer'] = 1

new_df.head(50)

# new_df[new_df['ID'].str.startswith('43-')].describe()
# Out:
#     Time           ID  Person  \
# 0      0  5-1_001-C01       1
# 1      1  5-1_001-C01       1
# 2      2  5-1_001-C01       1
# 3      3  5-1_001-C01       1
# 4      4  5-1_001-C01       1
# 5      5  5-1_001-C01       1
# 6      6  5-1_001-C01       1
# 7      7  5-1_001-C01       1
# 8      8  5-1_001-C01       1
# 9      9  5-1_001-C01       1
# 10    10  5-1_001-C01       1
# 11    11  5-1_001-C01       1
# 12    12  5-1_001-C01       1
# 13    13  5-1_001-C01       1
# 14    14  5-1_001-C01       1
# 15     0  5-1_001-C01       2
# 16     1  5-1_001-C01       2
# 17     2  5-1_001-C01       2
# 18     3  5-1_001-C01       2
# 19     4  5-1_001-C01       2
# 20     5  5-1_001-C01       2
# 21     6  5-1_001-C01       2
# 22     7  5-1_001-C01       2
# 23     8  5-1_001-C01       2
# 24     9  5-1_001-C01       2
[945.0, 655.0, 2.0, 948.0, 566.0, 2.0, 951.0, ...       0
# 27  [945.0, 655.0, 2.0, 948.0, 566.0, 2.0, 944.0, ...       0
# 28  [885.0, 653.0, 2.0, 923.0, 571.0, 2.0, 923.0, ...       0
# 29  [887.0, 652.0, 2.0, 899.0, 565.0, 2.0, 888.0, ...       0
# 30  [938.0, 653.0, 2.0, 940.0, 581.0, 2.0, 944.0, ...       0
# 31  [940.0, 656.0, 2.0, 933.0, 588.0, 2.0, 929.0, ...       0
# 32  [932.0, 648.0, 2.0, 911.0, 574.0, 2.0, 891.0, ...       0
# 33  [847.0, 654.0, 2.0, 857.0, 578.0, 2.0, 857.0, ...       0
# 34  [847.0, 654.0, 2.0, 843.0, 574.0, 2.0, 847.0, ...       0
# 35  [857.0, 650.0, 2.0, 850.0, 571.0, 2.0, 814.0, ...       0
# 36  [871.0, 657.0, 2.0, 860.0, 574.0, 2.0, 847.0, ...       0
# 37  [871.0, 655.0, 2.0, 881.0, 583.0, 2.0, 877.0, ...       0
# 38  [908.0, 646.0, 2.0, 943.0, 576.0, 2.0, 915.0, ...       0
# 39  [937.0, 660.0, 2.0, 937.0, 576.0, 2.0, 926.0, ...       0
# 40  [932.0, 660.0, 2.0, 937.0, 581.0, 2.0, 927.0, ...       0
# 41  [937.0, 655.0, 2.0, 936.0, 580.0, 2.0, 931.0, ...       0
# 42  [933.0, 656.0, 2.0, 938.0, 580.0, 2.0, 930.0, ...       0
# 43  [885.0, 653.0, 2.0, 919.0, 581.0, 2.0, 910.0, ...       0
# 44  [881.0, 650.0, 2.0, 892.0, 575.0, 2.0, 873.0, ...       0
# 45  [967.0, 660.0, 2.0, 977.0, 585.0, 2.0, 984.0, ...       0
# 46  [967.0, 656.0, 2.0, 992.0, 592.0, 2.0, 1006.0,...       0
# 47  [1030.0, 653.0, 2.0, 1027.0, 581.0, 2.0, 1030....       0
# 48  [1068.0, 661.0, 2.0, 1054.0, 590.0, 2.0, 1054....       0
# 49  [1073.0, 664.0, 2.0, 1059.0, 596.0, 2.0, 1098....       0

# %% [markdown]
# ### 정답을 붙인 데이터는 train_dropped_with_answer.csv로 저장한다

# %%
# new_df["ID_TYPE"] = new_df["ID"] + "_" + new_df["Person"].map(str)
# new_df = new_df.drop(['ID', 'Person'], axis=1)
# new_df = new_df[['Time', 'ID_TYPE', 'Keypoints', 'Answer']]

# new_df.rename(columns={'ID_TYPE':'ID'}, inplace=True)
# print(new_df)


new_df.to_csv('./train/train_dropped_with_answer.csv', mode='w', header = True, index=False)
# Out:
#         Time              ID  \
# 0          0   5-1_001-C01_1
# 1          1   5-1_001-C01_1
# 2          2   5-1_001-C01_1
# 3          3   5-1_001-C01_1
# 4          4   5-1_001-C01_1
# ...      ...             ...
# 478624    10  45-6_617-C03_1
# 478625    11  45-6_617-C03_1
# 478626    12  45-6_617-C03_1
# 478627    13  45-6_617-C03_1
# 478628    14  45-6_617-C03_1
#
#                                                 Keypoints  Answer
# 0       [967.0, 652.0, 2.0, 981.0, 575.0, 2.0, 991.0, ...       0
# 1       [970.0, 649.0, 2.0, 995.0, 575.0, 2.0, 1006.0,...       0
# 2       [1037.0, 649.0, 2.0, 1037.0, 572.0, 2.0, 1036....       0
# 3       [1077.0, 656.0, 2.0, 1059.0, 580.0, 2.0, 1055....       0
# 4       [1084.0, 656.0, 2.0, 1070.0, 576.0, 2.0, 1076....       0
# ...                                                   ...     ...
# 478624  [1074.0, 952.0, 2.0, 1042.0, 859.0, 2.0, 1030....       1
# 478625  [1011.0, 919.0, 2.0, 940.0, 855.0, 2.0, 969.0,...       1
# 478626  [862.0, 951.0, 2.0, 885.0, 855.0, 2.0, 920.0, ...       1
# 478627  [856.0, 959.0, 2.0, 852.0, 859.0, 2.0, 860.0, ...       1
# 478628  [856.0, 956.0, 2.0, 831.0, 862.0, 2.0, 823.0, ...       1
#
# [478629 rows x 4 columns]

# %% [markdown]
# ## Train/Test/Valid set 분리
# - `train_x, test_x, valid_x, train_t, test_t, valid_t`로 분리한다
# - 각 라벨에 대한 키포인트가 8개씩 달려있고, 이것들이 서로 떨어지면 안되기 때문에 `split_my_train_test()`을 작성해 진행함

# %% [markdown]
# ## Train/Test set 분리

# %%
# data_origin = new_df
data_origin = pd.read_csv('./train/train_dropped_with_answer.csv', sep=',')


data_origin["ID_TYPE"] = data_origin["ID"] + "_" + data_origin["Person"].map(str)
data_origin = data_origin.drop(['ID', 'Person'], axis=1)
data_origin = data_origin[['Time', 'ID_TYPE', 'Keypoints', 'Answer']]

data_origin.rename(columns={'ID_TYPE':'ID'}, inplace=True)
print(data_origin)


# print(new_df[new_df['ID']=="5-1_001-C01"])

KEYPOINT = 32
KEYPOINT_MOD = 26

# id_data = data_origin[['ID', 'Answer']].drop_duplicates(['ID'])
# id_data = id_data.reset_index(drop=True)

# id_data
# print(id_data)
# print(id_data.shape)

train_x, test_x, train_t, test_t = \
split_my_train_test(data_origin)

train_x.head(50)
# test_x.head(50)

print(train_x.shape)
print(train_t.shape)

# print(train_x_data)
# print(test_x_data)
# Out:
#         Time              ID  \
# 0          0   5-1_001-C01_1
# 1          1   5-1_001-C01_1
# 2          2   5-1_001-C01_1
# 3          3   5-1_001-C01_1
# 4          4   5-1_001-C01_1
# ...      ...             ...
# 199811     3  45-6_617-C03_1
# 199812     4  45-6_617-C03_1
# 199813     5  45-6_617-C03_1
# 199814     6  45-6_617-C03_1
# 199815     7  45-6_617-C03_1
#
#                                                 Keypoints  Answer
# 0       [967.0, 652.0, 2.0, 981.0, 575.0, 2.0, 991.0, ...       0
# 1       [1037.0, 649.0, 2.0, 1037.0, 572.0, 2.0, 1036....       0
# 2       [1084.0, 656.0, 2.0, 1070.0, 576.0, 2.0, 1076....       0
# 3       [1131.0, 654.0, 1.0, 1138.0, 570.0, 2.0, 1148....       0
# 4       [1091.0, 645.0, 2.0, 1066.0, 574.0, 2.0, 1082....       0
# ...                                                   ...     ...
# 199811  [1225.0, 952.0, 2.0, 1210.0, 850.0, 2.0, 1197....       1
# 199812  [1108.0, 947.0, 2.0, 1103.0, 849.0, 2.0, 1123....       1
# 199813  [1074.0, 952.0, 2.0, 1042.0, 859.0, 2.0, 1030....       1
# 199814  [862.0, 951.0, 2.0, 885.0, 855.0, 2.0, 920.0, ...       1
# 199815  [856.0, 956.0, 2.0, 831.0, 862.0, 2.0, 823.0, ...       1
#
# [199816 rows x 4 columns]
# 100%|█████████████████████████████████████| 17483/17483 [27:57<00:00, 10.42it/s]
# 100%|███████████████████████████████████████| 7494/7494 [05:56<00:00, 21.00it/s]
# (139864, 5)
# (17483,)

# %% [markdown]
# #### 필요 이상의 Time 값을 가진 데이터 확인
# - 이유를 알 수 없으나, 간혹 없어야하는 Time number를 가지고 있는 데이터가 있음
# - 해당 데이터를 찾아 삭제한 뒤, reindexing한다

# %%
train_x[ train_x['Time']==8 ]
# Out:
# Empty DataFrame
# Columns: [Time, ID, Person, Keypoints, Answer]
# Index: []

# %%
drop_index = train_x[ train_x['Time']==8 ].index
print(drop_index)
# new_test_df.loc[41448]
print(train_x.shape)

train_x_mod = train_x.drop(drop_index, inplace=False)
train_x_mod = train_x_mod.reset_index(drop=True, inplace=False)

train_t_mod = train_t.drop(drop_index, inplace=False)
train_t_mod = train_t_mod.reset_index(drop=True, inplace=False)

# new_test_df
print(train_x_mod.shape)
print(train_t_mod.shape)

################################################################

drop_index = test_x[ test_x['Time']==8 ].index
print(drop_index)
# new_test_df.loc[41448]
print(test_x.shape)

test_x_mod = test_x.drop(drop_index, inplace=False)
test_x_mod = test_x_mod.reset_index(drop=True, inplace=False)

test_t_mod = test_t.drop(drop_index, inplace=False)
test_t_mod = test_t_mod.reset_index(drop=True, inplace=False)

# new_test_df
print(test_x_mod.shape)
print(test_t_mod.shape)
# Out:
# Int64Index([], dtype='int64')
# (139864, 5)
# (139864, 5)
# (17483,)
# Int64Index([], dtype='int64')
# (59952, 5)
# (59952, 5)
# (7494,)

# %% [markdown]
# ## keypoints를 float으로 변환

# %%
# train_x_data = get_keypoints_in_float(train_x_mod[['Keypoints']])
# print(train_x_data.shape)

# %%
# np.savetxt('./train/train_x.csv',train_x_data,delimiter=",")

# train_t_mod.to_csv('./train/train_t.csv',  mode='w', header = True, index=False)
# train_t_mod

# %%
test_x_data = get_keypoints_in_float(test_x[['Keypoints']])
print(test_x_data.shape)
# Out:
# (59952,)
# 100%|████████████████████████████████████| 59952/59952 [00:59<00:00, 999.70it/s]
# (59952, 26)

# %% [markdown]
# ## 변환한 값을 .csv로 저장

# %%
np.savetxt('./train/test_x.csv',test_x_data,delimiter=",")

test_t_mod.to_csv('./train/test_t.csv',  mode='w', header = True, index=False)
test_t_mod
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 7489    1
# 7490    0
# 7491    0
# 7492    1
# 7493    1
# Name: Answer, Length: 7494, dtype: int64

# %% [markdown]
# ## Valid set을 위해 같은 과정을 train data로 한번 더 진행
# - 최종적으로 사용할 train/valid set 추출

# %%
train_x2, valid_x, train_t2, valid_t = \
split_my_train_test(train_x_mod)

train_x2.head(50)
# test_x.head(50)

print(train_x2.shape)
print(train_t2.shape)

# print(train_x_data)
# print(test_x_data)
# Out:
# 100%|█████████████████████████████████████| 12238/12238 [02:13<00:00, 91.84it/s]
# 100%|██████████████████████████████████████| 5245/5245 [00:50<00:00, 103.61it/s]
# (97904, 5)
# (12238,)

# %%
train_x_data = get_keypoints_in_float(train_x2[['Keypoints']])
print(train_x_data.shape)
np.savetxt('./train/train_x.csv',train_x_data,delimiter=",")
# Out:
# (97904,)
# 100%|████████████████████████████████████| 97904/97904 [03:13<00:00, 507.25it/s]
# (97904, 26)

# %%
train_t2.to_csv('./train/train_t.csv',  mode='w', header = True, index=False)
train_t2
# Out:
# 5509     0
# 3262     0
# 11356    0
# 14036    1
# 14897    0
#         ..
# 10474    1
# 4758     1
# 5890     0
# 6072     0
# 821      0
# Name: Answer, Length: 12238, dtype: object

# %%
valid_x_data = get_keypoints_in_float(valid_x[['Keypoints']])
print(valid_x_data.shape)
np.savetxt('./train/valid_x.csv',valid_x_data,delimiter=",")
# Out:
# (41960,)
# 100%|███████████████████████████████████| 41960/41960 [00:18<00:00, 2312.43it/s]
# (59952, 26)

# %%
valid_t.to_csv('./train/valid_t.csv',  mode='w', header = True, index=False)
valid_t
# Out:
# 5256     0
# 2375     0
# 6739     1
# 17293    0
# 1989     0
#         ..
# 6668     0
# 11053    0
# 12819    0
# 8501     0
# 2794     0
# Name: Answer, Length: 5245, dtype: object

# %% [markdown]
# # 데이터 체크를 위한 코드
# ## 데이터프레임에 주어진 값을 plt.scatter로 시각화

# %%
import matplotlib.pyplot as plt
import itertools


## for drawing graph

# def visualize_data(data, r_from, r_to):
def visualize_data(data):
    # fig = plt.figure()
    print(len(data))
    # ax = list()

    # for i in range(10):
    #     ax.append(fig.add_subplot(2,5,i+1))  # 2행 5열의 subplot을 만들어서 ax(list)안에 subplot을 저장
    #     ax[i].imshow(img_data[i].reshape(28,28), cmap='gray')
    
    color_cycle= itertools.cycle(["orange","pink","blue","brown","red","grey","yellow","green"])

#     for i in range(r_from, r_to+1):
    for i in range(0,len(data)):
#     for i in range(1, 6):
        data_xy = data[i].reshape(-1,2)
        x,y = zip(*data_xy)

        # plt.plot(result, 'ro')
        # fig.axis([])
        # plt.tight_layout()
        plt.scatter(x,y, color=next(color_cycle))
    plt.show()

# visualize_data(key_1)
# visualize_data(keypoint_arr)

# %%
import json
import numpy as np
import pandas as pd

import io

import os
import matplotlib.image as img
import matplotlib.pyplot as plt
import itertools
from tqdm import tqdm
from numpy import genfromtxt


train_x_data_DF = genfromtxt('./train/train_x.csv', delimiter=',')
train_t_mod_DF = pd.read_csv('./train/train_t.csv', sep=',')

valid_x_data_DF = genfromtxt('./train/valid_x.csv', delimiter=',')
valid_t_mod_DF = pd.read_csv('./train/valid_t.csv', sep=',')
# print(train_x_data_DF)
# print(train_x_data_DF.shape)
# print(train_t_mod_DF)

train_x_data = train_x_data_DF
train_t_mod = train_t_mod_DF

valid_x_data = valid_x_data_DF
valid_t_mod = valid_t_mod_DF

print(train_x_data)
print(train_x_data.shape)
print(type(train_x_data[0][0]))
print(train_t_mod.shape)

print(valid_x_data)
print(valid_x_data.shape)
print(type(valid_x_data[0][0]))
print(valid_t_mod.shape)
# Out:
# [[ 940.  648.  958. ...  414. 1044.  470.]
#  [ 940.  643.  966. ...  414. 1079.  479.]
#  [1014.  628. 1005. ...  413. 1061.  469.]
#  ...
#  [ 904.  963.  929. ...  508. 1013.  683.]
#  [ 904.  963.  929. ...  508. 1013.  683.]
#  [ 904.  963.  929. ...  508. 1013.  683.]]
# (97904, 26)
# <class 'numpy.float64'>
# (12238, 1)
# [[ 920.  844.  915. ...  549.  821.  512.]
#  [ 920.  844.  901. ...  587.  790.  643.]
#  [ 746.  844.  784. ...  562.  798.  627.]
#  ...
#  [1113.  597. 1105. ...  324.  990.  394.]
#  [1120.  602. 1106. ...  338.  991.  396.]
#  [1120.  602. 1127. ...  344. 1026.  408.]]
# (41960, 26)
# <class 'numpy.float64'>
# (5245, 1)

# %%
ans_index = train_t_mod[ train_t_mod['Answer']==1 ].index
# print(ans_index)
train = train_x_data.reshape(-1, 8, 26)

ans_train = train[ans_index]
# ans_train

AAA = 4
print(ans_train.min())
print(ans_train.max())

# print(ans_train[AAA].min()/3)
# print(ans_train[AAA].max()/3)

print(train_t_mod.loc[AAA])
# visualize_data(ans_train/3-50)
visualize_data(ans_train[AAA])
# visualize_data(ans_train[AAA]/3)
# Out:
# -9.0
# 1599.0
# Answer    0
# Name: 4, dtype: int64
# 8

# %% [markdown]
# ### 기존에 존재했던 모든 키포인트를 float으로 변환하여 csv로 저장하는 코드

# %%
data_origin = pd.read_csv('./train/train_with_answer.csv', sep=',')

# 5,6,41,42,43,45

answer_row = data_origin[data_origin['ID'].str.startswith('45-')].index
new_df = data_origin.loc[answer_row]

# new_df.head(50)


train_with_answer = get_keypoints_in_float(new_df[['Keypoints']])
print(train_with_answer.shape)
np.savetxt('./train/full_keypoint_in_float_45.csv',train_with_answer,delimiter=",")
# Out:
# (188318,)
#  38%|█████████████▎                     | 71938/188318 [00:58<03:43, 520.11it/s]
# ['920.0', ' 836.0', '0', ' 911.0', ' 655.0', '0', ' 1116.0', ' 642.0', '0', ' 1151.0', ' 739.0', '0', ' 911.0', ' 749.0', '0', ' 922.0', ' 906.0', '0', ' 1132.0', ' 693.0', '0', ' 1143.0', ' 531.0', '0', ' 1150.0', ' 423.0', '0', ' 1146.0', ' 268.0', '0', ' 1039.0', ' 564.0', '0', ' 1160.0', ' 507.0', '0', ' 1208.0', ' 405.0', '0', ' 1196.0', ' 509.0', '0', ' 1136.0', ' 647.0', '0', ' 1009.0', ' 684.0', '0']
# 100%|██████████████████████████████████| 188318/188318 [15:23<00:00, 203.90it/s]
# (188318, 26)

# %%
id_data = data_origin[['ID', 'Answer']]
id_data.to_csv('./train/full_id_with_answer.csv', mode='w', header = True, index=False)

id_data = data_origin[['ID', 'Answer']].drop_duplicates(['ID'])
id_data = id_data.reset_index(drop=True)
id_data.to_csv('./train/drop_id_with_answer.csv', mode='w', header = True, index=False)

# %% [markdown]
# ## 학습 결과 검증용 데이터를 다듬는 코드

# %%
test1 = np.array([[297.5,32.5,0.879,303.5,26.5,0.8567,290.5,21.5,0.8863,259.5,19.5,0.004,259.5,19.5,0.8719,302.5,100.5,0.7,211.5,75.5,0.7201,306.5,171.5,0.5957,212.5,141.5,0.727,322.5,216.5,0.7158,267.5,91.5,0.7563,257.5,254.5,0.5293,204.5,244.5,0.5735,234.5,364.5,0.4814,187.5,350.5,0.609,215.5,454.5,0.3623,175.5,451.5,0.6835],
[407.5,94.5,0.8299,411.5,84.5,0.0441,409.5,80.5,0.8822,375.5,62.5,0.0041,374.5,62.5,0.879,337.5,120.5,0.4974,300.5,114.5,0.4901,351.5,194.5,0.5832,326.5,201.5,0.6482,380.5,271.5,0.4442,387.5,274.5,0.6585,214.5,245.5,0.4022,205.5,243.5,0.484,199.5,363.5,0.4076,209.5,363.5,0.4409,142.5,461.5,0.3971,205.5,467.5,0.2153],
[386.5,111.5,0.8292,392.5,101.5,0.024,388.5,97.5,0.878,354.5,79.5,0.0041,354.5,79.5,0.8786,315.5,131.5,0.4119,282.5,125.5,0.553,341.5,202.5,0.5682,320.5,205.5,0.5933,379.5,270.5,0.3478,390.5,275.5,0.6404,173.5,238.5,0.3617,168.5,236.5,0.4315,165.5,361.5,0.2979,193.5,368.5,0.3429,134.5,471.5,0.1989,178.5,467.5,0.0949]])

# %%
print(test1.shape)
print(test2.shape)
# Out:
# (8, 51)
# (8, 51)

# %%
# Converting Joint infomation

# to AI Hub dataformat
def convert_annotation_to_aihub(keypoint):
    COCO_TO_AI = (
        (0,9),  (1,99),
        (2,99), (3,99),
        (4,99), (5,13),
        (6,12), (7,14),
        (8,11), (9,15),
        (10,10),(11,3),
        (12,2), (13,4),
        (14,1), (15,5),
        (16,0)
    )
    KakaoCOCO = 0
    AIHUB = 1
    
    new_keypoint = np.zeros(shape=(16,3))
#     print(new_keypoint)
    
    for cnt in range(0, 17):
        AI = COCO_TO_AI[cnt][AIHUB]
        COCO = COCO_TO_AI[cnt][KakaoCOCO]
#         print(str(cnt) + ' ')
#         print(str(COCO) + ' ' + str(AI))
        
        if (AI==99):
            continue
        new_keypoint[AI][0] = keypoint[COCO][0]
        new_keypoint[AI][1] = keypoint[COCO][1]
        new_keypoint[AI][2] = keypoint[COCO][2]*100
    
#     keypoint_int = np.round(new_keypoint, 0)
#     keypoint_int = np.asarray(keypoint_int, dtype = int)
#     return keypoint_int
    return new_keypoint
    
    
        
# to KAKAO API RESULT :  COCO(Common Objects in Context) dataformat
def convert_annotation_to_coco(keypoint):
    AI_TO_COCO = (
        (0,17-1), (1,15-1),
        (2,13-1), (3,12-1),
        (4,14-1), (5,16-1),
        (6,99),   (7,99),
        (8,99),   (9,1-1),
        (10,11-1),(11,9-1),
        (12,7-1), (13,6-1),
        (14,8-1), (15,10-1)
    )
    AIHUB = 0
    KakaoCOCO = 1
#     print(len(keypoint))
    
    new_keypoint = np.zeros(shape=(16,3))
#     print(new_keypoint)
    
    for cnt in range(0, 16):
        AI = AI_TO_COCO[cnt][AIHUB]
        COCO = AI_TO_COCO[cnt][KakaoCOCO]
        
        if (COCO==99):
            continue

        new_keypoint[COCO][0] = keypoint[AI][0]
        new_keypoint[COCO][1] = keypoint[AI][1]
        new_keypoint[COCO][2] = keypoint[AI][2]
    
#     keypoint_int = np.round(new_keypoint, 0)
#     keypoint_int = np.asarray(keypoint_int, dtype = int)
#     return keypoint_int
    return new_keypoint

# %%
def remove_unused_annotation(keypoint):
    # 학습데이터는 모두 2D데이터
    # 따라서, 사용하지 않는 값 (_, _, 2)을 제거
    keypoint = keypoint.reshape(-1, 3)
    result = np.delete(keypoint, 2, axis=1)
    
    # 실제 예측에서 사용할 수 없는 Annotation 제거
    result = np.delete(result, [6,7,8], axis=0)
    result = result.reshape(1,-1)
    
    return result

# %%
new_test1 = np.zeros(shape=(8,26))
for i in range(0,8):
    temp = convert_annotation_to_aihub(test1[i].reshape(-1, 3))
    new_test1[i] =  remove_unused_annotation(temp.reshape(1,-1))

print(test1.shape)
print(new_test1.shape)
print(new_test1.min())
print(new_test1.max())
visualize_data(new_test1[0:1])
# Out:
# (8, 51)
# (8, 26)
# 18.5
# 474.5
# 1

# %%
new_test2 = np.zeros(shape=(8,26))
for i in range(0,8):
    temp = convert_annotation_to_aihub(test2[i].reshape(-1, 3))
    new_test2[i] = remove_unused_annotation(temp.reshape(1,-1))

print(test2.shape)
print(new_test2.shape)

visualize_data(new_test2)
# Out:
# (8, 51)
# (8, 26)
# 8

# %% [markdown]
# ### 키포인트 파일을 가져와 정해진 frame 수에 맞게 조절하여, prediction에 이용하기 위한 값을 가져오는 코드

# %%
with open("./test_data/45-1_mod.json",'r') as j:
    contents=json.loads(j.read())
#     contents = list(contents)

    ID = []
    Keypoints = []
    Person_No = []

    for id in contents['images']:
#         print(id['img_path'])
        ID.append(id['img_path'].split("/")[-1])
#     ID.append(id['img_path'].split("/")[-1][:-8])

    for val in contents['annotations']:
        Person_No.append(val['person_no'])
        Keypoints.append(val['keypoints'])
    
    df = pd.DataFrame({"ID" : ID,
                       "Person" : Person_No,
                       "Keypoints" : Keypoints})
#     print(df)
    
df.reset_index(inplace=True)
df.rename(columns={'index':'Time'}, inplace=True)
# df

dfindex = df[ df['Time']%2 == 0].index
df.drop(dfindex, inplace=True)
df.drop('Time', axis=1, inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop(8, inplace=True)
df
# Out:
#                      ID  Person  \
# 0  45-1_001-C01_019.jpg       1
# 1  45-1_001-C01_049.jpg       1
# 2  45-1_001-C01_079.jpg       1
# 3  45-1_001-C01_099.jpg       1
# 4  45-1_001-C01_119.jpg       1
# 5  45-1_001-C01_139.jpg       1
# 6  45-1_001-C01_159.jpg       1
# 7  45-1_001-C01_179.jpg       1
#
#                                            Keypoints
# 0  [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 941.0, ...
# 1  [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 930.0, ...
# 2  [931.0, 731.0, 2.0, 933.0, 583.0, 2.0, 930.0, ...
# 3  [928.0, 727.0, 2.0, 947.0, 580.0, 2.0, 958.0, ...
# 4  [928.0, 727.0, 2.0, 947.0, 580.0, 2.0, 958.0, ...
# 5  [928.0, 727.0, 2.0, 947.0, 580.0, 2.0, 958.0, ...
# 6  [928.0, 727.0, 2.0, 947.0, 580.0, 2.0, 958.0, ...
# 7  [928.0, 727.0, 2.0, 947.0, 580.0, 2.0, 958.0, ...

# %%
# dt_key = get_keypoints_in_float(df[['Keypoints']])
df_key = df[['Keypoints']]

# print(df_key)
# print(type(df_key.loc[i][i]))

df_key_arr = np.zeros(shape=(8,26))

for i in range(0,8):
    temp = np.array(df_key.loc[i][0])
    df_key_arr[i] = remove_unused_annotation(temp)

print(type(df_key_arr))
# print(df_key_arr)


visualize_data(df_key_arr)
# Out:
# <class 'numpy.ndarray'>
# 8
